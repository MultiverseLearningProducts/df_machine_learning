# %%
from IPython.display import HTML
from IPython.display import Javascript

from IPython.display import display

# Taken from https://stackoverflow.com/questions/31517194/how-to-hide-one-specific-cell-input-or-output-in-ipython-notebook
tag = HTML("""<script>
code_show=true; 
function code_toggle() {
    if (code_show){
        $('div.cell.code_cell.rendered.selected div.input').hide();
    } else {
        $('div.cell.code_cell.rendered.selected div.input').show();
    }
    code_show = !code_show
} 
$( document ).ready(code_toggle);

var flagHighlight=0;
var flagHighlightCode = 0;
var flagMagnifyCell = 0;
var flagMagnifyCode =0;
var flagMagnifyOutputs=0;
var flagEnlarge = 0;
var flagHighlightOutput = 0;

function enlarge_markdown(){
    
if(flagEnlarge==0){
flagEnlarges = 1;
document.getElementById('button7').classList.toggle('active_button');
var els = document.getElementsByClassName('text_cell');
var i;
for(i=0;i<els.length;i++){
els[i].classList.toggle('enlarged');}}
else{
flagEnlarge = 0;
document.getElementById('button7').classList.toggle('active_button');
var els = document.getElementsByClassName('text_cell');
var i;
for(i=0;i<els.length;i++){
els[i].classList.remove('enlarged');
}};};


function magnify_outputs(){
    
if(flagMagnifyOutputs==0){
flagMagnifyOutputs = 1;
document.getElementById('button5').classList.toggle('active_button');
var els = document.getElementsByClassName('output_wrapper');
var i;
for(i=0;i<els.length;i++){
els[i].classList.toggle('magnified_output');}}
else{
flagMagnifyOutputs = 0;
document.getElementById('button5').classList.toggle('active_button');
var els = document.getElementsByClassName('output_wrapper');
var i;
for(i=0;i<els.length;i++){
els[i].classList.remove('magnified_output');
}};};

function magnify_output_lines(){
    
if(flagHighlightOutput==0){
flagHighlightOutput = 1;
document.getElementById('button6').classList.toggle('active_button');
var els = document.getElementsByClassName('output_wrapper');
var i;
for(i=0;i<els.length;i++){
els[i].classList.toggle('magnified_output_lines');}}
else{flagHighlightOutput = 0;
document.getElementById('button6').classList.toggle('active_button');
var els = document.getElementsByClassName('output_wrapper');
var i;
for(i=0;i<els.length;i++){
els[i].classList.remove('magnified_output_lines');
}};};


function highlight_cell(){
    
if(flagHighlight==0){
flagHighlight = 1;
document.getElementById('button4').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.toggle('highlighted');}}
else{flagHighlight = 0;
document.getElementById('button4').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.remove('highlighted');
}};};


function highlight_code(){   
if(flagHighlightCode==0){

flagHighlightCode = 1;
document.getElementById('button3').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.toggle('highlighted_code');}}   
else{flagHighlightCode = 0;
document.getElementById('button3').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.remove('highlighted_code');
}};};

function magnify_cell(){   
if(flagMagnifyCell==0){
flagMagnifyCell = 1;
document.getElementById('button2').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.toggle('magnified_cell');}}   
else{flagMagnifyCell = 0;
document.getElementById('button2').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.remove('magnified_cell');
}};};

function magnify_code(){   
if(flagMagnifyCode==0){
flagMagnifyCode = 1;
document.getElementById('button1').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.toggle('magnified_code');}}   
else{flagMagnifyCode = 0;
document.getElementById('button1').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.remove('magnified_code');
}};};


document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend", "<div id='help_box'></div>");
document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend","<img src= 'https://img.flaticon.com/icons/png/512/25/25186.png?size=1200x630f&pad=10,10,10,10&ext=png&bg=FFFFFFFF' id='mvlogo'>")
document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend", "<div class='hidden' id='tooltip2'><p>click the eye to hide/show tools</p></div>");
var help_box = document.getElementById('help_box');

help_box.classList.add('floater');

help_box.innerHTML = "<h2 id='heading'><b>Visual tools</b></h2><button id='button1' class='clean_buttons'>Magnify lines </button><button id='button2'class = 'clean_buttons' >Enlarge cells</button><button id='button3' class = 'clean_buttons' >highlight lines</button><button id='button4' class = 'clean_buttons' >highlight cell</button>";
help_box.innerHTML +="<button id='button5' class='clean_buttons'>Enlarge</button><button id='button6' class='clean_buttons'>Highlight</button>"
help_box.innerHTML += "<button id='button7' class='clean_buttons'>enlarge</button"
help_box.innerHTML+= "<p class='sections' id='code_heading'><b>Code</b></p>"
help_box.innerHTML+= "<p class='sections' id='output_heading'><b>Outputs</b></p>"
help_box.innerHTML+= "<p class='sections' id='markdown_heading'><b>Markdowns</b></p>"
help_box.innerHTML +="<p id='credit'>logo credit to https://www.flaticon.com/free-icon/eye-open_25186 <br>  used under open license: Attribution 3.0 Unported (CC BY 3.0)<br> Coded by N.Griffiths employed by Muliverse </p>"
document.body.appendChild(help_box);

document.getElementById('button7').addEventListener('click',function(){
   enlarge_markdown();});
    
document.getElementById('button6').addEventListener('click',function(){
    magnify_output_lines();});

document.getElementById('button5').addEventListener('click',function(){
    magnify_outputs();});
    
document.getElementById('button4').addEventListener('click',function(){
    highlight_cell();});

document.getElementById('button3').addEventListener('click',function(){
    highlight_code();});

document.getElementById('button2').addEventListener('click',function(){
    magnify_cell();});

document.getElementById('button1').addEventListener('click',function(){
    magnify_code();});
 
document.getElementById('mvlogo').addEventListener('click',function(){  
document.getElementById('help_box').classList.toggle('hidden');}); 
 
 
document.getElementById('mvlogo').addEventListener('mouseover',function(){  
document.getElementById('tooltip2').classList.toggle('hidden');});

document.getElementById('mvlogo').addEventListener('mouseout',function(){  
document.getElementById('tooltip2').classList.toggle('hidden');});


</script>
<a id='boilerplate' href="javascript:code_toggle()">change js running visual-aids</a>.


<style>

.hidden{
display:none;
}

#credit{
position: fixed;
top:65.5vh;
left:81vw;
font-size:0.9vmin;
}
#boilerplate{
color:white;
}

#boilerplate:hover{
color:blue;
}

#tooltip2{
position:fixed;
z-index:1001;
left:80vw;
top:18vh;
font-size:1.5vh;
background-color:white;
}

.floater{
background-color:#FFFFFF;
color:#003b49;
border-style:solid;
border-color:#003b49;
borderwidth:0.1vh;
z-index:1000;
position:fixed;
left: 80vw;
Top: 20vh;
height: 53vh;
width: 18vw;

}

#heading{
position:fixed;
top:21vh;
left:80vw;
margin: 1vh 1vh 1vh  1vh;
font-size:3vmin;}

.clean_buttons{
padding: 0px 0px 0px 0px;
background-color:#d0d3d4;
color:#003b49;
cursor: pointer;
width:8vw;
height:6vh;
font-size:2vmin;
border-width:0.1vh;
}
#button1{
position:fixed;
top:31vh;
left:80.5vw;
}
#button2{
position:fixed;
top:31vh;
left:89vw;
}
#button3{
position:fixed;
top:38vh;
left:80.5vw;
}
#button4{
position:fixed;
top:38vh;
left:89vw;
}
#button5{
position:fixed;
top:48.5vh;
left:80.5vw;
}
#button6{
position:fixed;
top:48.5vh;
left:89vw;
}
#button7{
position:fixed;
top:58vh;
left: 84vw;
}
.active_button{
background:#003b49;
color:#d0d3d4;
}

.sections{
font-size: 2vmin;
left:82vw;
}
#code_heading{
position:fixed;
top:28vh;
}
#output_heading{
position:fixed;
top:45vh;
}
#markdown_heading{
position:fixed;
top:55vh;
}

#mvlogo{
width:18vw;
height:8vh;
object-fit: cover;
position:fixed;
z-index:1000;
left: 80vw;
top: 10vh;
border: 0.5vh solid #003b49;
cursor: pointer;
}

.highlighted :hover{
background-color:#fcfaeb;
}

.highlighted_code div pre :hover{
background-color:yellow;
}

.magnified_code div pre span:hover{
margin-top:3vh;
margin-bottom:3vh;
height:30px;
width:auto;
font-size:130%;}

.magnified_cell div pre{
padding: 6px 0px 6px 0px;
}

.magnified_cell div{
font-size:120%;
line-height:120%;
}

.magnified_output *{
font-size: 115%;
}

.magnified_output_lines :hover{
background-color:#FFFF99;
color:purple;

}

.enlarged *  {
font-size:120%;
line-height:120%;

}



</style>
""")

display(tag)
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#     if (code_show){
#         $('div.cell.code_cell.rendered.selected div.input').hide();
#     } else {
#         $('div.cell.code_cell.rendered.selected div.input').show();
#     }
#     code_show = !code_show
# }
# $( document ).ready(code_toggle);
#
# var flagHighlight=0;
# var flagHighlightCode = 0;
# var flagMagnifyCell = 0;
# var flagMagnifyCode =0;
# var flagMagnifyOutputs=0;
# var flagEnlarge = 0;
# var flagHighlightOutput = 0;
#
# function enlarge_markdown(){
#
# if(flagEnlarge==0){
# flagEnlarges = 1;
# document.getElementById('button7').classList.toggle('active_button');
# var els = document.getElementsByClassName('text_cell');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.toggle('enlarged');}}
# else{
# flagEnlarge = 0;
# document.getElementById('button7').classList.toggle('active_button');
# var els = document.getElementsByClassName('text_cell');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.remove('enlarged');
# }};};
#
#
# function magnify_outputs(){
#
# if(flagMagnifyOutputs==0){
# flagMagnifyOutputs = 1;
# document.getElementById('button5').classList.toggle('active_button');
# var els = document.getElementsByClassName('output_wrapper');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.toggle('magnified_output');}}
# else{
# flagMagnifyOutputs = 0;
# document.getElementById('button5').classList.toggle('active_button');
# var els = document.getElementsByClassName('output_wrapper');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.remove('magnified_output');
# }};};
#
# function magnify_output_lines(){
#
# if(flagHighlightOutput==0){
# flagHighlightOutput = 1;
# document.getElementById('button6').classList.toggle('active_button');
# var els = document.getElementsByClassName('output_wrapper');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.toggle('magnified_output_lines');}}
# else{flagHighlightOutput = 0;
# document.getElementById('button6').classList.toggle('active_button');
# var els = document.getElementsByClassName('output_wrapper');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.remove('magnified_output_lines');
# }};};
#
#
# function highlight_cell(){
#
# if(flagHighlight==0){
# flagHighlight = 1;
# document.getElementById('button4').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.toggle('highlighted');}}
# else{flagHighlight = 0;
# document.getElementById('button4').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.remove('highlighted');
# }};};
#
#
# function highlight_code(){
# if(flagHighlightCode==0){
#
# flagHighlightCode = 1;
# document.getElementById('button3').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.toggle('highlighted_code');}}
# else{flagHighlightCode = 0;
# document.getElementById('button3').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.remove('highlighted_code');
# }};};
#
# function magnify_cell(){
# if(flagMagnifyCell==0){
# flagMagnifyCell = 1;
# document.getElementById('button2').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.toggle('magnified_cell');}}
# else{flagMagnifyCell = 0;
# document.getElementById('button2').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.remove('magnified_cell');
# }};};
#
# function magnify_code(){
# if(flagMagnifyCode==0){
# flagMagnifyCode = 1;
# document.getElementById('button1').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.toggle('magnified_code');}}
# else{flagMagnifyCode = 0;
# document.getElementById('button1').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.remove('magnified_code');
# }};};
#
#
# document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend", "<div id='help_box'></div>");
# document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend","<img src= 'https://img.flaticon.com/icons/png/512/25/25186.png?size=1200x630f&pad=10,10,10,10&ext=png&bg=FFFFFFFF' id='mvlogo'>")
# document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend", "<div class='hidden' id='tooltip2'><p>click the eye to hide/show tools</p></div>");
# var help_box = document.getElementById('help_box');
#
# help_box.classList.add('floater');
#
# help_box.innerHTML = "<h2 id='heading'><b>Visual tools</b></h2><button id='button1' class='clean_buttons'>Magnify lines </button><button id='button2'class = 'clean_buttons' >Enlarge cells</button><button id='button3' class = 'clean_buttons' >highlight lines</button><button id='button4' class = 'clean_buttons' >highlight cell</button>";
# help_box.innerHTML +="<button id='button5' class='clean_buttons'>Enlarge</button><button id='button6' class='clean_buttons'>Highlight</button>"
# help_box.innerHTML += "<button id='button7' class='clean_buttons'>enlarge</button"
# help_box.innerHTML+= "<p class='sections' id='code_heading'><b>Code</b></p>"
# help_box.innerHTML+= "<p class='sections' id='output_heading'><b>Outputs</b></p>"
# help_box.innerHTML+= "<p class='sections' id='markdown_heading'><b>Markdowns</b></p>"
# help_box.innerHTML +="<p id='credit'>logo credit to https://www.flaticon.com/free-icon/eye-open_25186 <br>  used under open license: Attribution 3.0 Unported (CC BY 3.0)<br> Coded by N.Griffiths employed by Muliverse </p>"
# document.body.appendChild(help_box);
#
# document.getElementById('button7').addEventListener('click',function(){
#    enlarge_markdown();});
#
# document.getElementById('button6').addEventListener('click',function(){
#     magnify_output_lines();});
#
# document.getElementById('button5').addEventListener('click',function(){
#     magnify_outputs();});
#
# document.getElementById('button4').addEventListener('click',function(){
#     highlight_cell();});
#
# document.getElementById('button3').addEventListener('click',function(){
#     highlight_code();});
#
# document.getElementById('button2').addEventListener('click',function(){
#     magnify_cell();});
#
# document.getElementById('button1').addEventListener('click',function(){
#     magnify_code();});
#
# document.getElementById('mvlogo').addEventListener('click',function(){
# document.getElementById('help_box').classList.toggle('hidden');});
#
#
# document.getElementById('mvlogo').addEventListener('mouseover',function(){
# document.getElementById('tooltip2').classList.toggle('hidden');});
#
# document.getElementById('mvlogo').addEventListener('mouseout',function(){
# document.getElementById('tooltip2').classList.toggle('hidden');});
#
#
# </script>
# <a id='boilerplate' href="javascript:code_toggle()">change js running visual-aids</a>.
#
#
# <style>
#
# .hidden{
# display:none;
# }
#
# #credit{
# position: fixed;
# top:65.5vh;
# left:81vw;
# font-size:0.9vmin;
# }
# #boilerplate{
# color:white;
# }
#
# #boilerplate:hover{
# color:blue;
# }
#
# #tooltip2{
# position:fixed;
# z-index:1001;
# left:80vw;
# top:18vh;
# font-size:1.5vh;
# background-color:white;
# }
#
# .floater{
# background-color:#FFFFFF;
# color:#003b49;
# border-style:solid;
# border-color:#003b49;
# borderwidth:0.1vh;
# z-index:1000;
# position:fixed;
# left: 80vw;
# Top: 20vh;
# height: 53vh;
# width: 18vw;
#
# }
#
# #heading{
# position:fixed;
# top:21vh;
# left:80vw;
# margin: 1vh 1vh 1vh  1vh;
# font-size:3vmin;}
#
# .clean_buttons{
# padding: 0px 0px 0px 0px;
# background-color:#d0d3d4;
# color:#003b49;
# cursor: pointer;
# width:8vw;
# height:6vh;
# font-size:2vmin;
# border-width:0.1vh;
# }
# #button1{
# position:fixed;
# top:31vh;
# left:80.5vw;
# }
# #button2{
# position:fixed;
# top:31vh;
# left:89vw;
# }
# #button3{
# position:fixed;
# top:38vh;
# left:80.5vw;
# }
# #button4{
# position:fixed;
# top:38vh;
# left:89vw;
# }
# #button5{
# position:fixe

# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Web Scraping
#
# _Author: Dave Yerrington (SF)_
#
# ---

# %% [markdown]
# ## Learning Objectives
# - Revisit how to locate elements on a webpage
# - Aquire unstructure data from the internet using Beautiful soup.
# - Discuss limitations associated with simple requests and urllib libraries
# - Introduce Selenium as a solution, and implement a scraper using selenium

# %% [markdown]
# ## Lesson Guide
#
# - [Introduction](#intro)
# - [Building a web scraper](#building-scraper)
# - [Retrieving data from the HTML page](#retrieving-data)
#     - [Retrieving the restaurant names](#retrieving-names)
#     - [Challenge: Retrieving the restaurant locations](#retrieving-locations)
#     - [Retrieving the restaurant prices](#retrieving-prices)
#
#
# - [Summary](#summary)

# %% [markdown]
# <a id="intro"></a>
# ## Introduction
#
# In this codealong lesson, we'll build a web scraper using requests and BeautifulSoup. We will also explore how to use a headless browser called Selenium.
#
# We'll begin by scraping OpenTable's DC listings. We're interested in knowing the restaurant's **name, location, price, and how many people booked it today.**
#
# OpenTable provides all of this information on this given page: http://www.opentable.com/washington-dc-restaurant-listings
#
# Let's inspect the elements of this page to assure we can find each of the bits of information in which we're interested.
#
# ---

# %% [markdown]
# <a id="building-scraper"></a>
# ## Building a web scraper
#
# Now, let's build a web scraper for OpenTable using urllib and Beautiful Soup:

# %%
# import our necessary first packages
from bs4 import BeautifulSoup
import requests

# %%
# set the url we want to visit
url = "http://www.opentable.com/washington-dc-restaurant-listings"

# visit that url, and grab the html of said page
html = requests.get(url)

# %% [markdown]
# At this point, what is in html?

# %%
# .text returns the request content in Unicode
html.text[:500]
# Out:
# '           <!DOCTYPE html><html lang="en"><head><meta charset="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=9; IE=8; IE=7; IE=EDGE"/> <title>Restaurant Reservation Availability</title>    <meta  name="robots" content="noindex,nofollow" > </meta>     <link rel="shortcut icon" href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon.ico" type="image/x-icon"/><link rel="icon" href="//components.otstatic.com/components/favicon/1.0.6/favicon/favicon-16.png" sizes="16x16"/><l'

# %% [markdown]
# We will need to convert this html objct into a soup object so we can parse it using python and BS4

# %%
# convert this into a soup object
soup = BeautifulSoup(html.text, 'html.parser')

# %% [markdown]
# <a id="retrieving-data"></a>
# ### Retrieving data from the HTML page

# %% [markdown]
# Let's first find each restaurant name listed on the page we've loaded. How do we find the page location of the restaurant? (Hint: We need to know where in the **HTML** the restaurant element is housed.) In order to find the HTML that renders the restaurant location, we can use Google Chrome's Inspect tool:
#
# > http://www.opentable.com/washington-dc-restaurant-listings
#
# > 1. Visit the URL above.
#
# > 2. Right-click on an element you are interested in, then choose Inspect (in Chrome).
#
# > 3. This will open the Developer Tools and show the HTML used to render the selected page element.
#
# > Throughout this lesson, we will use this method to find tags associated with elements of the page we want to scrape.
#
# See if you can find the restaurant name on the page. Keep in mind there are many restaurants loaded on the page.

# %%
# print the restaurant names
soup.find_all(name='span', attrs={'class':'rest-row-name-text'})
# Out:
# [<span class="rest-row-name-text">Jennyfers</span>,
#  <span class="rest-row-name-text">Elsie Bogan</span>,
#  <span class="rest-row-name-text">Et Club</span>,
#  <span class="rest-row-name-text">In</span>,
#  <span class="rest-row-name-text">Sed</span>,
#  <span class="rest-row-name-text">Parkway</span>,
#  <span class="rest-row-name-text">Distinctio</span>,
#  <span class="rest-row-name-text">Hertha Inlet</span>,
#  <span class="rest-row-name-text">Pfeffer</span>,
#  <span class="rest-row-name-text">Dignissimos Cassin</span>,
#  <span class="rest-row-name-text">August Nikolaus</span>,
#  <span class="rest-row-name-text">Rodriguez</span>,
#  <span class="rest-row-name-text">Yost</span>,
#  <span class="rest-row-name-text">Liana Spring</span>,
#  <span class="rest-row-name-text">1228 Lebsack</span>,
#  <span class="rest-row-name-text">Rem Throughway</span>,
#  <span class="rest-row-name-text">Trycia Walter</span>,
#  <span class="rest-row-name-text">Angelitas</span>,
#  <span class="rest-row-name-text">Facere Unions</span>,
#  <span class="rest-row-name-text">Rerum Island</span>,
#  <span class="rest-row-name-text">Iste Baumbach</span>,
#  <span class="rest-row-name-text">Quae Lights</span>,
#  <span class="rest-row-name-text">Harum Heller</span>,
#  <span class="rest-row-name-text">1260 Stroman</span>,
#  <span class="rest-row-name-text">Squares</span>,
#  <span class="rest-row-name-text">Tempore Kshlerin</span>,
#  <span class="rest-row-name-text">Ibrahims</span>,
#  <span class="rest-row-name-text">482 Glover</span>,
#  <span class="rest-row-name-text">Illo</span>,
#  <span class="rest-row-name-text">1024 Romaguera</span>,
#  <span class="rest-row-name-text">Niko Drive</span>,
#  <span class="rest-row-name-text">Gottlieb Pines</span>,
#  <span class="rest-row-name-text">Island</span>,
#  <span class="rest-row-name-text">Joshua Boyer</span>,
#  <span class="rest-row-name-text">Esse</span>,
#  <span class="rest-row-name-text">Ward</span>,
#  <span class="rest-row-name-text">690 Sauer</span>,
#  <span class="rest-row-name-text">Heights</span>,
#  <span class="rest-row-name-text">Santiago Cummerata</span>,
#  <span class="rest-row-name-text">Reichel</span>,
#  <span class="rest-row-name-text">Oval</span>,
#  <span class="rest-row-name-text">Agloe Bar &amp; Grill</span>,
#  <span class="rest-row-name-text">1438 Crist</span>,
#  <span class="rest-row-name-text">View</span>,
#  <span class="rest-row-name-text">Adelbert Mante</span>,
#  <span class="rest-row-name-text">Eligendi</span>,
#  <span class="rest-row-name-text">Bennys</span>,
#  <span class="rest-row-name-text">Sabrynas</span>,
#  <span class="rest-row-name-text">Inventore Drives</span>,
#  <span class="rest-row-name-text">Zechariah Prairie</span>,
#  <span class="rest-row-name-text">Walker Shore</span>,
#  <span class="rest-row-name-text">Cordells</span>,
#  <span class="rest-row-name-text">Et Brakus</span>,
#  <span class="rest-row-name-text">Id</span>,
#  <span class="rest-row-name-text">Laborum Swift</span>,
#  <span class="rest-row-name-text">Sierra Garden</span>,
#  <span class="rest-row-name-text">In</span>,
#  <span class="rest-row-name-text">Springs</span>,
#  <span class="rest-row-name-text">724 Armstrong</span>,
#  <span class="rest-row-name-text">315 Kemmer</span>,
#  <span class="rest-row-name-text">Crest</span>,
#  <span class="rest-row-name-text">Necessitatibus Mante</span>,
#  <span class="rest-row-name-text">Quidem Senger</span>,
#  <span class="rest-row-name-text">Volkman</span>,
#  <span class="rest-row-name-text">Skyla Braun</span>,
#  <span class="rest-row-name-text">Elis</span>,
#  <span class="rest-row-name-text">Alisha Isle</span>,
#  <span class="rest-row-name-text">Velit Valley</span>,
#  <span class="rest-row-name-text">1210 Schinner</span>,
#  <span class="rest-row-name-text">Trail</span>,
#  <span class="rest-row-name-text">Commodi Heidenreich</span>,
#  <span class="rest-row-name-text">Leon Lueilwitz</span>,
#  <span class="rest-row-name-text">Est</span>,
#  <span class="rest-row-name-text">Elisabeth Weber</span>,
#  <span class="rest-row-name-text">Grimes</span>,
#  <span class="rest-row-name-text">Explicabo</span>,
#  <span class="rest-row-name-text">Welch</span>,
#  <span class="rest-row-name-text">Laurianes</span>,
#  <span class="rest-row-name-text">A</span>,
#  <span class="rest-row-name-text">Izabella Sipes</span>,
#  <span class="rest-row-name-text">Dolorem Inlet</span>,
#  <span class="rest-row-name-text">Laura Locks</span>,
#  <span class="rest-row-name-text">Et Turnpike</span>,
#  <span class="rest-row-name-text">Kaylis</span>,
#  <span class="rest-row-name-text">Okuneva</span>,
#  <span class="rest-row-name-text">Orn Rest</span>,
#  <span class="rest-row-name-text">Consequatur</span>,
#  <span class="rest-row-name-text">282 Nikolaus</span>,
#  <span class="rest-row-name-text">Koss</span>,
#  <span class="rest-row-name-text">Bradtke</span>,
#  <span class="rest-row-name-text">Giannis</span>,
#  <span class="rest-row-name-text">Frederick McDermott</span>,
#  <span class="rest-row-name-text">Nam Heights</span>,
#  <span class="rest-row-name-text">Dolore</span>,
#  <span class="rest-row-name-text">Isle</span>,
#  <span class="rest-row-name-text">In Points</span>,
#  <span class="rest-row-name-text">Aut Bahringer</span>,
#  <span class="rest-row-name-text">Corporis Doyle</span>,
#  <span class="rest-row-name-text">45 Rempel</span>,
#  <span class="rest-row-name-text">Minima Goyette</span>]

# %% [markdown]
# It is important to always keep in mind the data types that were returned. Note this is a `list`, and we know that immediately by observing the outer square brackets and commas separating each tag.
#
# Next, note the elements of the list are `Tag` objects, not strings. (If they were strings, they would be surrounded by quotes.) The Beautiful Soup authors chose to display a `Tag` object visually as a text representation of the tag and its contents. However, being an object, it has many methods that we can call on it. For example, next we will use the `encode_contents()` method to return the tag's contents encoded as a Python string.
#
# <a id="retrieving-names"></a>
# #### Retrieving the restaurant names
#
# Now that we found a list of tags containing the restaurant names, let's think how we can loop through them all one-by-one. In the following cell, we'll print out the name (and **only** the clean name, not the rest of the html) of each restaurant.

# %%
# for each element you find, print out the restaurant name
for entry in soup.find_all(name='span', attrs={'class':'rest-row-name-text'}):
    print(entry.text)
# Out:
# Jennyfers
# Elsie Bogan
# Et Club
# In
# Sed
# Parkway
# Distinctio
# Hertha Inlet
# Pfeffer
# Dignissimos Cassin
# August Nikolaus
# Rodriguez
# Yost
# Liana Spring
# 1228 Lebsack
# Rem Throughway
# Trycia Walter
# Angelitas
# Facere Unions
# Rerum Island
# Iste Baumbach
# Quae Lights
# Harum Heller
# 1260 Stroman
# Squares
# Tempore Kshlerin
# Ibrahims
# 482 Glover
# Illo
# 1024 Romaguera
# Niko Drive
# Gottlieb Pines
# Island
# Joshua Boyer
# Esse
# Ward
# 690 Sauer
# Heights
# Santiago Cummerata
# Reichel
# Oval
# Agloe Bar & Grill
# 1438 Crist
# View
# Adelbert Mante
# Eligendi
# Bennys
# Sabrynas
# Inventore Drives
# Zechariah Prairie
# Walker Shore
# Cordells
# Et Brakus
# Id
# Laborum Swift
# Sierra Garden
# In
# Springs
# 724 Armstrong
# 315 Kemmer
# Crest
# Necessitatibus Mante
# Quidem Senger
# Volkman
# Skyla Braun
# Elis
# Alisha Isle
# Velit Valley
# 1210 Schinner
# Trail
# Commodi Heidenreich
# Leon Lueilwitz
# Est
# Elisabeth Weber
# Grimes
# Explicabo
# Welch
# Laurianes
# A
# Izabella Sipes
# Dolorem Inlet
# Laura Locks
# Et Turnpike
# Kaylis
# Okuneva
# Orn Rest
# Consequatur
# 282 Nikolaus
# Koss
# Bradtke
# Giannis
# Frederick McDermott
# Nam Heights
# Dolore
# Isle
# In Points
# Aut Bahringer
# Corporis Doyle
# 45 Rempel
# Minima Goyette

# %% [markdown]
# Great!
#
# <a id="retrieving-locations"></a>
# #### Challenge: Retrieving the restaurant locations
#
# Can you repeat that process for finding the location? For example, barmini by Jose Andres is in the location listed as "Penn Quarter" in our search results.

# %%
# first, see if you can identify the location for all elements -- print it out

# %%
# now print out EACH location for the restaurants

# %% [markdown]
# <a id="retrieving-prices"></a>
# #### Retrieving the restaurant prices

# %% [markdown]
# Ok, we've figured out the restaurant name and location. Now we need to grab the price (number of dollar signs on a scale of one to four) for each restaurant. We'll follow the same process.

# %%
# print out all prices
soup.find_all('div', {'class':'rest-row-pricing'})
# Out:
# [<div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>]

# %%
# print out EACH number of dollar signs per restaurant
# this one is trickier to eliminate the html. Hint: try a nested find
for entry in soup.find_all('div', {'class':'rest-row-pricing'}):
    print(entry.find('i').text)
# Out:
#   $    $    $    $
#   $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $
#   $    $
#   $    $
#   $    $
#   $    $    $
#   $    $
#   $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $
#   $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $
#   $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $

# %% [markdown]
# That looks great, but what if I wanted just the number of dollar signs per restaurant? Can you figure out a way to simply print out the number of dollar signs per restaurant listed?

# %%
# print the number of dollars signs per restaurant
# A:

# %% [markdown]
# Click here for solution
#
# <span style ='color:white'>
#
# for entry in soup.find_all('div', {'class':'rest-row-pricing'}):
#     price = entry.find('i').text
#     print(price.count('$'))

# %% [markdown]
# What's going on here? Discuss.
#
# How can we debug this? Any ideas?

# %% [markdown]
# # Class Exercise
#
# - Using a website of your choice, scrape some key attributes and put them into a dataframe

# %%
html =  requests.get('')
soup_cl = BeautifulSoup(html.text, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-13-86506cd3977d> in <module>
# ----> 1 html =  requests.get('')
#       2 soup_cl = BeautifulSoup(html.text, 'html.parser')
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     514             hooks=hooks,
#     515         )
# --> 516         prep = self.prepare_request(req)
#     517
#     518         proxies = proxies or {}
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     447
#     448         p = PreparedRequest()
# --> 449         p.prepare(
#     450             method=request.method.upper(),
#     451             url=request.url,
#
# ~\anaconda3\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     312
#     313         self.prepare_method(method)
# --> 314         self.prepare_url(url, params)
#     315         self.prepare_headers(headers)
#     316         self.prepare_cookies(cookies)
#
# ~\anaconda3\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     386             error = error.format(to_native_string(url, 'utf8'))
#     387
# --> 388             raise MissingSchema(error)
#     389
#     390         if not host:
#
# MissingSchema: Invalid URL '': No schema supplied. Perhaps you meant http://?

# %% [markdown]
# ### Summary
#
# In this lesson, we used the Beautiful Soup library to locate elements on a website then scrape their text. We also used the Selenium headless browser to run JavaScript first before retrieving the page contents.
